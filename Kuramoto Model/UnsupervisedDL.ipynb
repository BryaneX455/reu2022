# %%
from kuramoto import Kuramoto
from kuramoto.db_metrics import *
from sklearn.ensemble import RandomForestClassifier as rf

# %%
nodes = 100
r = 250
num_samples = 1000

df100_250_1000_L_FF = gen_KM(nodes, r, num_samples, edge_var="L", random_K=False, half_sync=False)
df100_250_1000_L_FF
# Out:
#             0         1         2         3         4         5         6  \
# 0    3.960581  3.980857  4.001080  4.021251  4.041371  4.061444  4.081471
# 1    1.198956  1.198178  1.197384  1.196572  1.195740  1.194887  1.194013
# 2    3.839103  3.854369  3.869648  3.884937  3.900237  3.915546  3.930863
# 3    5.017859  5.008040  4.998173  4.988258  4.978294  4.968281  4.958218
# 4    5.068294  5.072448  5.076607  5.080771  5.084941  5.089117  5.093301
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  2.349505  2.359785  2.370056  2.380319  2.390573  2.400819  2.411057
# 996  4.484606  4.497345  4.510133  4.522967  4.535845  4.548766  4.561728
# 997  1.453708  1.444780  1.435794  1.426751  1.417651  1.408496  1.399284
# 998  1.579224  1.585292  1.591328  1.597333  1.603306  1.609248  1.615158
# 999  2.447438  2.461995  2.476568  2.491156  2.505760  2.520379  2.535014
#
#             7         8         9  ...     24996     24997     24998  \
# 0    4.101453  4.121393  4.141294  ...  1.366358  1.367416  1.368479
# 1    1.193115  1.192193  1.191245  ...  6.042922  6.047684  6.052468
# 2    3.946188  3.961520  3.976856  ...  3.763669  3.756022  3.748284
# 3    4.948106  4.937944  4.927730  ...  5.034550  5.038978  5.043394
# 4    5.097493  5.101693  5.105901  ...  1.977931  1.964421  1.951059
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  2.421287  2.431509  2.441722  ... -0.491591 -0.511318 -0.530969
# 996  4.574727  4.587763  4.600833  ...  0.478121  0.479883  0.481648
# 997  1.390017  1.380695  1.371319  ...  3.665057  3.666776  3.668513
# 998  1.621036  1.626881  1.632693  ...  1.158148  1.154665  1.151200
# 999  2.549664  2.564329  2.579009  ...  0.641753  0.637567  0.633355
#
#         24999  # Edges  # Nodes  Min Degree  Max Degree  Diameter  \
# 0    1.369547      732      100          14          17         4
# 1    6.057275      997      100          18          24         3
# 2    3.740456     1067      100          17          26         3
# 3    5.047797     1658      100          25          43         2
# 4    1.937845     1220      100          20          31         3
# ..        ...      ...      ...         ...         ...       ...
# 995 -0.550539     1082      100          17          28         3
# 996  0.483417      936      100          16          23         3
# 997  3.670265      954      100          15          24         3
# 998  1.147751     1309      100          22          34         3
# 999  0.629118     1783      100          22          43         2
#
#      Concentrated
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 995             0
# 996             0
# 997             0
# 998             0
# 999             0
#
# [1000 rows x 25006 columns]

# %%
import pandas as pd

path = f'./datasets/NWS_{nodes}_{r}_{num_samples}_low_F_F.csv'
df100_250_1000_L_FF.to_csv(path, index=False)

# %%
df_NS = pd.read_csv('./datasets/NWS_100_250_1000_low_F_F.csv')
df_NS
# Out:
#             0         1         2         3         4         5         6  \
# 0    3.960581  3.980857  4.001080  4.021251  4.041371  4.061444  4.081471
# 1    1.198956  1.198178  1.197384  1.196572  1.195740  1.194887  1.194013
# 2    3.839103  3.854369  3.869648  3.884937  3.900237  3.915546  3.930863
# 3    5.017859  5.008040  4.998173  4.988258  4.978294  4.968281  4.958218
# 4    5.068294  5.072448  5.076607  5.080771  5.084941  5.089117  5.093301
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  2.349505  2.359785  2.370056  2.380319  2.390573  2.400819  2.411057
# 996  4.484606  4.497345  4.510133  4.522967  4.535845  4.548766  4.561728
# 997  1.453708  1.444780  1.435794  1.426751  1.417651  1.408496  1.399284
# 998  1.579224  1.585292  1.591328  1.597333  1.603306  1.609248  1.615158
# 999  2.447438  2.461995  2.476568  2.491156  2.505760  2.520379  2.535014
#
#             7         8         9  ...     24996     24997     24998  \
# 0    4.101453  4.121393  4.141294  ...  1.366358  1.367416  1.368479
# 1    1.193115  1.192193  1.191245  ...  6.042922  6.047684  6.052468
# 2    3.946188  3.961520  3.976856  ...  3.763669  3.756022  3.748284
# 3    4.948106  4.937944  4.927730  ...  5.034550  5.038978  5.043394
# 4    5.097493  5.101693  5.105901  ...  1.977931  1.964421  1.951059
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  2.421287  2.431509  2.441722  ... -0.491591 -0.511318 -0.530969
# 996  4.574727  4.587763  4.600833  ...  0.478121  0.479883  0.481648
# 997  1.390017  1.380695  1.371319  ...  3.665057  3.666776  3.668513
# 998  1.621036  1.626881  1.632693  ...  1.158148  1.154665  1.151200
# 999  2.549664  2.564329  2.579009  ...  0.641753  0.637567  0.633355
#
#         24999  # Edges  # Nodes  Min Degree  Max Degree  Diameter  \
# 0    1.369547      732      100          14          17         4
# 1    6.057275      997      100          18          24         3
# 2    3.740456     1067      100          17          26         3
# 3    5.047797     1658      100          25          43         2
# 4    1.937845     1220      100          20          31         3
# ..        ...      ...      ...         ...         ...       ...
# 995 -0.550539     1082      100          17          28         3
# 996  0.483417      936      100          16          23         3
# 997  3.670265      954      100          15          24         3
# 998  1.147751     1309      100          22          34         3
# 999  0.629118     1783      100          22          43         2
#
#      Concentrated
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 995             0
# 996             0
# 997             0
# 998             0
# 999             0
#
# [1000 rows x 25006 columns]

# %%
df_NS.describe()
# Out:
#                  0            1            2            3            4  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      3.216348     3.216478     3.216608     3.216738     3.216868
# std       1.778487     1.778810     1.779195     1.779641     1.780150
# min       0.003487     0.012237     0.011899     0.010916     0.000922
# 25%       1.751620     1.751702     1.757773     1.754283     1.752208
# 50%       3.270699     3.270645     3.274323     3.273112     3.276311
# 75%       4.683107     4.683457     4.682652     4.686076     4.687792
# max       6.263436     6.274062     6.290859     6.307626     6.324364
#
#                  5            6            7            8            9  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean      3.216998     3.217128     3.217258     3.217388     3.217518  ...
# std       1.780721     1.781354     1.782048     1.782805     1.783623  ...
# min      -0.009073    -0.019069    -0.029064    -0.039059    -0.049053  ...
# 25%       1.752610     1.748841     1.743564     1.733255     1.730747  ...
# 50%       3.275639     3.285398     3.275801     3.278456     3.281613  ...
# 75%       4.692165     4.698245     4.702591     4.697685     4.688369  ...
# max       6.341074     6.357759     6.374421     6.391060     6.407679  ...
#
#              24996        24997        24998        24999      # Edges  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      3.110022     3.110151     3.110278     3.110404  1250.895000
# std       2.999649     3.006376     3.013103     3.019831   270.149482
# min      -7.515686    -7.537994    -7.560475    -7.583139   701.000000
# 25%       1.005857     1.003938     1.003458     1.003032  1035.500000
# 50%       3.109548     3.105657     3.103245     3.104745  1249.000000
# 75%       5.263399     5.265802     5.265514     5.263496  1463.250000
# max      11.819809    11.831899    11.843883    11.855764  1800.000000
#
#        # Nodes  Min Degree   Max Degree     Diameter  Concentrated
# count   1000.0  1000.00000  1000.000000  1000.000000        1000.0
# mean     100.0    19.15900    31.857000     2.930000           0.0
# std        0.0     3.15431     7.433694     0.577437           0.0
# min      100.0    14.00000    15.000000     2.000000           0.0
# 25%      100.0    17.00000    26.000000     3.000000           0.0
# 50%      100.0    19.00000    32.000000     3.000000           0.0
# 75%      100.0    21.00000    38.000000     3.000000           0.0
# max      100.0    28.00000    50.000000     8.000000           0.0
#
# [8 rows x 25006 columns]

# %%
nodes = 100
r = 250
num_samples = 1000

df100_250_1000_L_FT = gen_KM(nodes, r, num_samples, edge_var="L", random_K=False, half_sync=True)
df100_250_1000_L_FT
# Out:
#             0         1         2         3         4         5         6  \
# 0    2.538290  2.526587  2.514937  2.503345  2.491814  2.480347  2.468947
# 1    0.468590  0.480132  0.491762  0.503479  0.515276  0.527150  0.539096
# 2    1.000790  1.008950  1.017122  1.025300  1.033485  1.041672  1.049860
# 3    2.260463  2.250930  2.241419  2.231934  2.222477  2.213050  2.203656
# 4    0.305140  0.318549  0.332113  0.345828  0.359688  0.373688  0.387822
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  1.267037  1.274794  1.282488  1.290115  1.297673  1.305160  1.312574
# 996  1.432313  1.433921  1.435546  1.437189  1.438847  1.440520  1.442208
# 997  1.817374  1.818044  1.818677  1.819272  1.819831  1.820351  1.820834
# 998  1.598435  1.596684  1.594969  1.593290  1.591647  1.590039  1.588468
# 999  3.005648  2.993710  2.981661  2.969505  2.957243  2.944881  2.932420
#
#             7         8         9  ...     24996     24997     24998  \
# 0    2.457618  2.446363  2.435186  ...  1.750595  1.750395  1.750194
# 1    0.551110  0.563187  0.575322  ...  1.597403  1.597346  1.597292
# 2    1.058046  1.066228  1.074403  ...  1.799247  1.799048  1.798852
# 3    2.194298  2.184978  2.175699  ...  1.504440  1.504229  1.504024
# 4    0.402086  0.416471  0.430973  ...  1.671325  1.670887  1.670455
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  1.319911  1.327170  1.334348  ...  1.601760  1.601731  1.601701
# 996  1.443910  1.445625  1.447351  ...  1.598281  1.598453  1.598621
# 997  1.821279  1.821686  1.822055  ...  1.654862  1.654885  1.654906
# 998  1.586932  1.585432  1.583967  ...  1.535048  1.535157  1.535266
# 999  2.919864  2.907217  2.894483  ...  1.657823  1.657757  1.657690
#
#         24999  # Edges  # Nodes  Min Degree  Max Degree  Diameter  \
# 0    1.749993      833      100          14          22         3
# 1    1.597241     1758      100          25          44         2
# 2    1.798659     1262      100          19          31         3
# 3    1.503825     1102      100          17          27         3
# 4    1.670029     1521      100          23          38         2
# ..        ...      ...      ...         ...         ...       ...
# 995  1.601670     1050      100          18          25         3
# 996  1.598784     1104      100          17          28         3
# 997  1.654928      823      100          16          19         4
# 998  1.535375     1419      100          20          38         3
# 999  1.657624      895      100          15          24         3
#
#      Concentrated
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 995             1
# 996             1
# 997             1
# 998             1
# 999             1
#
# [1000 rows x 25006 columns]

# %%
path = f'./datasets/NWS_{nodes}_{r}_{num_samples}_low_F_T.csv'
df100_250_1000_L_FT.to_csv(path, index=False)

# %%
df_S = pd.read_csv('./datasets/NWS_100_250_1000_low_F_T.csv')
df_S
# Out:
#             0         1         2         3         4         5         6  \
# 0    2.538290  2.526587  2.514937  2.503345  2.491814  2.480347  2.468947
# 1    0.468590  0.480132  0.491762  0.503479  0.515276  0.527150  0.539096
# 2    1.000790  1.008950  1.017122  1.025300  1.033485  1.041672  1.049860
# 3    2.260463  2.250930  2.241419  2.231934  2.222477  2.213050  2.203656
# 4    0.305140  0.318549  0.332113  0.345828  0.359688  0.373688  0.387822
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  1.267037  1.274794  1.282488  1.290115  1.297673  1.305160  1.312574
# 996  1.432313  1.433921  1.435546  1.437189  1.438847  1.440520  1.442208
# 997  1.817374  1.818044  1.818677  1.819272  1.819831  1.820351  1.820834
# 998  1.598435  1.596684  1.594969  1.593290  1.591647  1.590039  1.588468
# 999  3.005648  2.993710  2.981661  2.969505  2.957243  2.944881  2.932420
#
#             7         8         9  ...     24996     24997     24998  \
# 0    2.457618  2.446363  2.435186  ...  1.750595  1.750395  1.750194
# 1    0.551110  0.563187  0.575322  ...  1.597403  1.597346  1.597292
# 2    1.058046  1.066228  1.074403  ...  1.799247  1.799048  1.798852
# 3    2.194298  2.184978  2.175699  ...  1.504440  1.504229  1.504024
# 4    0.402086  0.416471  0.430973  ...  1.671325  1.670887  1.670455
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  1.319911  1.327170  1.334348  ...  1.601760  1.601731  1.601701
# 996  1.443910  1.445625  1.447351  ...  1.598281  1.598453  1.598621
# 997  1.821279  1.821686  1.822055  ...  1.654862  1.654885  1.654906
# 998  1.586932  1.585432  1.583967  ...  1.535048  1.535157  1.535266
# 999  2.919864  2.907217  2.894483  ...  1.657823  1.657757  1.657690
#
#         24999  # Edges  # Nodes  Min Degree  Max Degree  Diameter  \
# 0    1.749993      833      100          14          22         3
# 1    1.597241     1758      100          25          44         2
# 2    1.798659     1262      100          19          31         3
# 3    1.503825     1102      100          17          27         3
# 4    1.670029     1521      100          23          38         2
# ..        ...      ...      ...         ...         ...       ...
# 995  1.601670     1050      100          18          25         3
# 996  1.598784     1104      100          17          28         3
# 997  1.654928      823      100          16          19         4
# 998  1.535375     1419      100          20          38         3
# 999  1.657624      895      100          15          24         3
#
#      Concentrated
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 995             1
# 996             1
# 997             1
# 998             1
# 999             1
#
# [1000 rows x 25006 columns]

# %%
from sklearn.decomposition import DictionaryLearning

# %%
X_t = df_S.loc[:, '0':'24999'].values

# %%
X = X_t.T

# %%
w_t = X_t[0].reshape(-1,250)
print(w_t.shape)
plt.imshow(w_t);
# Out:
# (100, 250)

# %%
dict_learner = DictionaryLearning(n_components=16,
                                  transform_algorithm='lasso_cd', 
                                  transform_alpha=0.1,
                                  random_state=42)

# %%
X_t_transformed = dict_learner.fit_transform(X)
print(X_t_transformed.shape)
plt.imshow(X_t_transformed);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [177], in <cell line: 1>()
# ----> 1 X_t_transformed = dict_learner.fit_transform(X)
#       2 print(X_t_transformed.shape)
#       3 plt.imshow(X_t_transformed)
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/decomposition/_dict_learning.py:1699, in DictionaryLearning.fit(self, X, y)
#    1696 else:
#    1697     n_components = self.n_components
# -> 1699 V, U, E, self.n_iter_ = dict_learning(
#    1700     X,
#    1701     n_components,
#    1702     alpha=self.alpha,
#    1703     tol=self.tol,
#    1704     max_iter=self.max_iter,
#    1705     method=self.fit_algorithm,
#    1706     method_max_iter=self.transform_max_iter,
#    1707     n_jobs=self.n_jobs,
#    1708     code_init=self.code_init,
#    1709     dict_init=self.dict_init,
#    1710     verbose=self.verbose,
#    1711     random_state=random_state,
#    1712     return_n_iter=True,
#    1713     positive_dict=self.positive_dict,
#    1714     positive_code=self.positive_code,
#    1715 )
#    1716 self.components_ = U
#    1717 self.error_ = E
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/decomposition/_dict_learning.py:678, in dict_learning(X, n_components, alpha, max_iter, tol, method, n_jobs, dict_init, code_init, callback, verbose, random_state, return_n_iter, positive_dict, positive_code, method_max_iter)
#     672     print(
#     673         "Iteration % 3i (elapsed time: % 3is, % 4.1fmn, current cost % 7.3f)"
#     674         % (ii, dt, dt / 60, current_cost)
#     675     )
#     677 # Update code
# --> 678 code = sparse_encode(
#     679     X,
#     680     dictionary,
#     681     algorithm=method,
#     682     alpha=alpha,
#     683     init=code,
#     684     n_jobs=n_jobs,
#     685     positive=positive_code,
#     686     max_iter=method_max_iter,
#     687     verbose=verbose,
#     688 )
#     690 # Update dictionary in place
#     691 _update_dict(
#     692     dictionary,
#     693     X,
#    (...)
#     697     positive=positive_dict,
#     698 )
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/decomposition/_dict_learning.py:373, in sparse_encode(X, dictionary, gram, cov, algorithm, n_nonzero_coefs, alpha, copy_cov, init, max_iter, n_jobs, check_input, verbose, positive)
#     370         regularization = 1.0
#     372 if effective_n_jobs(n_jobs) == 1 or algorithm == "threshold":
# --> 373     code = _sparse_encode(
#     374         X,
#     375         dictionary,
#     376         gram,
#     377         cov=cov,
#     378         algorithm=algorithm,
#     379         regularization=regularization,
#     380         copy_cov=copy_cov,
#     381         init=init,
#     382         max_iter=max_iter,
#     383         check_input=False,
#     384         verbose=verbose,
#     385         positive=positive,
#     386     )
#     387     return code
#     389 # Enter parallel code block
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/decomposition/_dict_learning.py:156, in _sparse_encode(X, dictionary, gram, cov, algorithm, regularization, copy_cov, init, max_iter, check_input, verbose, positive)
#     144     # Not passing in verbose=max(0, verbose-1) because Lars.fit already
#     145     # corrects the verbosity level.
#     146     lasso_lars = LassoLars(
#     147         alpha=alpha,
#     148         fit_intercept=False,
#    (...)
#     154         max_iter=max_iter,
#     155     )
# --> 156     lasso_lars.fit(dictionary.T, X.T, Xy=cov)
#     157     new_code = lasso_lars.coef_
#     158 finally:
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/linear_model/_least_angle.py:1128, in Lars.fit(self, X, y, Xy)
#    1125     noise = rng.uniform(high=self.jitter, size=len(y))
#    1126     y = y + noise
# -> 1128 self._fit(
#    1129     X,
#    1130     y,
#    1131     max_iter=max_iter,
#    1132     alpha=alpha,
#    1133     fit_path=self.fit_path,
#    1134     normalize=_normalize,
#    1135     Xy=Xy,
#    1136 )
#    1138 return self
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/linear_model/_least_angle.py:1063, in Lars._fit(self, X, y, max_iter, alpha, fit_path, normalize, Xy)
#    1061 for k in range(n_targets):
#    1062     this_Xy = None if Xy is None else Xy[:, k]
# -> 1063     alphas, _, self.coef_[k], n_iter_ = lars_path(
#    1064         X,
#    1065         y[:, k],
#    1066         Gram=Gram,
#    1067         Xy=this_Xy,
#    1068         copy_X=self.copy_X,
#    1069         copy_Gram=True,
#    1070         alpha_min=alpha,
#    1071         method=self.method,
#    1072         verbose=max(0, self.verbose - 1),
#    1073         max_iter=max_iter,
#    1074         eps=self.eps,
#    1075         return_path=False,
#    1076         return_n_iter=True,
#    1077         positive=self.positive,
#    1078     )
#    1079     self.alphas_.append(alphas)
#    1080     self.n_iter_.append(n_iter_)
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/linear_model/_least_angle.py:169, in lars_path(X, y, Xy, Gram, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     164 if X is None and Gram is not None:
#     165     raise ValueError(
#     166         "X cannot be None if Gram is not None"
#     167         "Use lars_path_gram to avoid passing X and y."
#     168     )
# --> 169 return _lars_path_solver(
#     170     X=X,
#     171     y=y,
#     172     Xy=Xy,
#     173     Gram=Gram,
#     174     n_samples=None,
#     175     max_iter=max_iter,
#     176     alpha_min=alpha_min,
#     177     method=method,
#     178     copy_X=copy_X,
#     179     eps=eps,
#     180     copy_Gram=copy_Gram,
#     181     verbose=verbose,
#     182     return_path=return_path,
#     183     return_n_iter=return_n_iter,
#     184     positive=positive,
#     185 )
#
# File ~/miniforge3/envs/env_tf/lib/python3.9/site-packages/sklearn/linear_model/_least_angle.py:776, in _lars_path_solver(X, y, Xy, Gram, n_samples, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     773 coef[active] = prev_coef[active] + gamma_ * least_squares
#     775 # update correlations
# --> 776 Cov -= gamma_ * corr_eq_dir
#     778 # See if any coefficient has changed sign
#     779 if drop and method == "lasso":
#     780
#     781     # handle the case when idx is not length of 1
#
# KeyboardInterrupt:

# %%
w_t_hat = w_t_transformed @ dict_learner.components_
rec_error = np.mean(np.sum((w_t_hat - w_t) ** 2, axis=1) / np.sum(w_t ** 2, axis=1))
print(f'Reconstruction error: {rec_error}')
# Out:
# Reconstruction error: 6.086573892312226e-05

# %%
V = dict_learner.fit(w_t).components_
patch_size = (10, 25)

plt.figure(figsize=(10, 8))
for i, comp in enumerate(V[:25]):
    plt.subplot(10, 10, i + 1)
    plt.imshow(comp.reshape(patch_size), cmap=plt.cm.gray_r, interpolation="nearest")
    plt.xticks(())
    plt.yticks(())
plt.suptitle(
    "Dictionary learned from face patches\n",
    fontsize=16,
)
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)

# %%
w_t = X[1].reshape(-1,250)
print(w_t.shape)
plt.imshow(w_t);
# Out:
# (100, 250)

# %%
w_t_transformed = dict_learner.fit_transform(w_t)
print(w_t_transformed.shape)
plt.imshow(w_t_transformed);
# Out:
# (100, 16)

# %%
w_t_hat = w_t_transformed @ dict_learner.components_
rec_error = np.mean(np.sum((w_t_hat - w_t) ** 2, axis=1) / np.sum(w_t ** 2, axis=1))
print(f'Reconstruction error: {rec_error}')
# Out:
# Reconstruction error: 5.144939274529689e-05

# %%
V = dict_learner.fit(w_t).components_
patch_size = (10, 25)

plt.figure(figsize=(10, 8))
for i, comp in enumerate(V[:25]):
    plt.subplot(10, 10, i + 1)
    plt.imshow(comp.reshape(patch_size), cmap=plt.cm.gray_r, interpolation="nearest")
    plt.xticks(())
    plt.yticks(())
plt.suptitle(
    "Dictionary learned from face patches\n",
    fontsize=16,
)
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)

# %%
df_NS
# Out:
#             0         1         2         3         4         5         6  \
# 0    3.960581  3.980857  4.001080  4.021251  4.041371  4.061444  4.081471
# 1    1.198956  1.198178  1.197384  1.196572  1.195740  1.194887  1.194013
# 2    3.839103  3.854369  3.869648  3.884937  3.900237  3.915546  3.930863
# 3    5.017859  5.008040  4.998173  4.988258  4.978294  4.968281  4.958218
# 4    5.068294  5.072448  5.076607  5.080771  5.084941  5.089117  5.093301
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  2.349505  2.359785  2.370056  2.380319  2.390573  2.400819  2.411057
# 996  4.484606  4.497345  4.510133  4.522967  4.535845  4.548766  4.561728
# 997  1.453708  1.444780  1.435794  1.426751  1.417651  1.408496  1.399284
# 998  1.579224  1.585292  1.591328  1.597333  1.603306  1.609248  1.615158
# 999  2.447438  2.461995  2.476568  2.491156  2.505760  2.520379  2.535014
#
#             7         8         9  ...     24996     24997     24998  \
# 0    4.101453  4.121393  4.141294  ...  1.366358  1.367416  1.368479
# 1    1.193115  1.192193  1.191245  ...  6.042922  6.047684  6.052468
# 2    3.946188  3.961520  3.976856  ...  3.763669  3.756022  3.748284
# 3    4.948106  4.937944  4.927730  ...  5.034550  5.038978  5.043394
# 4    5.097493  5.101693  5.105901  ...  1.977931  1.964421  1.951059
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  2.421287  2.431509  2.441722  ... -0.491591 -0.511318 -0.530969
# 996  4.574727  4.587763  4.600833  ...  0.478121  0.479883  0.481648
# 997  1.390017  1.380695  1.371319  ...  3.665057  3.666776  3.668513
# 998  1.621036  1.626881  1.632693  ...  1.158148  1.154665  1.151200
# 999  2.549664  2.564329  2.579009  ...  0.641753  0.637567  0.633355
#
#         24999  # Edges  # Nodes  Min Degree  Max Degree  Diameter  \
# 0    1.369547      732      100          14          17         4
# 1    6.057275      997      100          18          24         3
# 2    3.740456     1067      100          17          26         3
# 3    5.047797     1658      100          25          43         2
# 4    1.937845     1220      100          20          31         3
# ..        ...      ...      ...         ...         ...       ...
# 995 -0.550539     1082      100          17          28         3
# 996  0.483417      936      100          16          23         3
# 997  3.670265      954      100          15          24         3
# 998  1.147751     1309      100          22          34         3
# 999  0.629118     1783      100          22          43         2
#
#      Concentrated
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 995             0
# 996             0
# 997             0
# 998             0
# 999             0
#
# [1000 rows x 25006 columns]

# %%
X_f = df_NS.loc[:, '0':'24999'].values

# %%
w_f = X_f[0].reshape(-1,250)
print(w_f.shape)
plt.imshow(w_f);
# Out:
# (100, 250)

# %%
dict_learner = DictionaryLearning(n_components=16,
                                  transform_algorithm='lasso_cd', 
                                  transform_alpha=0.1,
                                  random_state=42)

# %%
w_f_transformed = dict_learner.fit_transform(w_f)
print(w_f_transformed.shape)
plt.imshow(w_f_transformed);
# Out:
# (100, 16)

# %%
w_f_hat = w_f_transformed @ dict_learner.components_
rec_error = np.mean(np.sum((w_f_hat - w_f) ** 2, axis=1) / np.sum(w_f ** 2, axis=1))
print(f'Reconstruction error: {rec_error}')
# Out:
# Reconstruction error: 0.0007772975644376174

# %%
V = dict_learner.fit(w_f).components_
patch_size = (10, 25)

plt.figure(figsize=(10, 8))
for i, comp in enumerate(V[:25]):
    plt.subplot(10, 10, i + 1)
    plt.imshow(comp.reshape(patch_size), cmap=plt.cm.gray_r, interpolation="nearest")
    plt.xticks(())
    plt.yticks(())
plt.suptitle(
    "Dictionary learned from face patches\n",
    fontsize=16,
)
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)

# %%
w_f = X_f[1].reshape(-1,250)
print(w_f.shape)
plt.imshow(w_f);
# Out:
# (100, 250)

# %%
w_f_transformed = dict_learner.fit_transform(w_f)
print(w_f_transformed.shape)
plt.imshow(w_f_transformed);
# Out:
# (100, 16)

# %%
w_f_hat = w_f_transformed @ dict_learner.components_
rec_error = np.mean(np.sum((w_f_hat - w_f) ** 2, axis=1) / np.sum(w_f ** 2, axis=1))
print(f'Reconstruction error: {rec_error}')
# Out:
# Reconstruction error: 0.0008167941567573686

# %%
V = dict_learner.fit(w_f).components_
patch_size = (10, 25)

plt.figure(figsize=(10, 8))
for i, comp in enumerate(V[:25]):
    plt.subplot(10, 10, i + 1)
    plt.imshow(comp.reshape(patch_size), cmap=plt.cm.gray_r, interpolation="nearest")
    plt.xticks(())
    plt.yticks(())
plt.suptitle(
    "Dictionary learned from face patches\n",
    fontsize=16,
)
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)

# %%
nodes = 20
r = 250
num_samples = 100

df20_250_100_L_FT = gen_KM(nodes, r, num_samples, edge_var="L", random_K=False, half_sync=True)
df20_250_100_L_FT
# Out:
#            0         1         2         3         4         5         6  \
# 0   1.259810  1.260752  1.261690  1.262625  1.263555  1.264480  1.265400
# 1   1.745964  1.740321  1.734717  1.729153  1.723631  1.718152  1.712717
# 2   3.083754  3.071008  3.058101  3.045032  3.031805  3.018421  3.004883
# 3   3.138635  3.126578  3.114401  3.102107  3.089697  3.077174  3.064542
# 4   0.458779  0.468400  0.478060  0.487758  0.497491  0.507255  0.517047
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.017446  1.030054  1.042649  1.055226  1.067780  1.080307  1.092801
# 96  0.731236  0.742645  0.754075  0.765522  0.776982  0.788450  0.799923
# 97  0.032873  0.044517  0.056281  0.068163  0.080160  0.092270  0.104491
# 98  2.208660  2.200448  2.192225  2.183994  2.175757  2.167517  2.159276
# 99  1.353028  1.355018  1.357021  1.359036  1.361062  1.363099  1.365147
#
#            7         8         9  ...      4996      4997      4998      4999  \
# 0   1.266315  1.267224  1.268128  ...  1.317301  1.317509  1.317714  1.317914
# 1   1.707327  1.701985  1.696689  ...  1.368738  1.368879  1.369017  1.369153
# 2   2.991192  2.977353  2.963366  ...  1.350412  1.350686  1.350954  1.351217
# 3   3.051802  3.038959  3.026014  ...  1.693862  1.694166  1.694465  1.694759
# 4   0.526865  0.536704  0.546562  ...  1.367265  1.367498  1.367728  1.367952
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  1.105260  1.117677  1.130049  ...  1.986659  1.986556  1.986456  1.986357
# 96  0.811396  0.822865  0.834326  ...  1.702422  1.702327  1.702235  1.702144
# 97  0.116821  0.129256  0.141795  ...  1.507474  1.507198  1.506926  1.506661
# 98  2.151038  2.142804  2.134577  ...  1.510247  1.510111  1.509978  1.509848
# 99  1.367204  1.369271  1.371346  ...  1.573989  1.573756  1.573527  1.573303
#
#     # Edges  # Nodes  Min Degree  Max Degree  Diameter  Concentrated
# 0       188       20          17          19         2             1
# 1       174       20          16          19         2             1
# 2       190       20          19          19         1             1
# 3       173       20          16          19         2             1
# 4       184       20          17          19         2             1
# ..      ...      ...         ...         ...       ...           ...
# 95      190       20          19          19         1             1
# 96      190       20          19          19         1             1
# 97      189       20          18          19         2             1
# 98      190       20          19          19         1             1
# 99      189       20          18          19         2             1
#
# [100 rows x 5006 columns]

# %%
X_t = df20_250_100_L_FT.loc[:, 0:4999].values
X = X_t.T

# %%
dict_learner = DictionaryLearning(n_components=16,
                                  transform_algorithm='lasso_cd', 
                                  transform_alpha=0.1,
                                  random_state=42)

# %%
X_t_transformed = dict_learner.fit_transform(X)
print(X_t_transformed.shape)
# Out:
# (5000, 16)

# %%
import seaborn as sns
sns.heatmap(X_t_transformed, cbar=False);

# %%
X_t_hat = X_t_transformed @ dict_learner.components_
rec_error = np.mean(np.sum((X_t_hat - X) ** 2, axis=1) / np.sum(X ** 2, axis=1))
print(f'Reconstruction error: {rec_error}')
# Out:
# Reconstruction error: 0.005520974618384713

# %% [markdown]
# ## NMF

# %%
import numpy as np
from tqdm import trange

from NNetwork import NNetwork as nn
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from sklearn import svm
from sklearn import metrics, model_selection
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# %%
def coding(X, W, H0, 
          r=None, 
          a1=0, #L1 regularizer
          a2=0, #L2 regularizer
          sub_iter=[5], 
          stopping_grad_ratio=0.0001, 
          nonnegativity=True,
          subsample_ratio=1):
    """
    Find \hat{H} = argmin_H ( || X - WH||_{F}^2 + a1*|H| + a2*|H|_{F}^{2} ) within radius r from H0
    Use row-wise projected gradient descent
    """
    H1 = H0.copy()
    i = 0
    dist = 1
    idx = np.arange(X.shape[1])
    if subsample_ratio>1:  # subsample columns of X and solve reduced problem (like in SGD)
        idx = np.random.randint(X.shape[1], size=X.shape[1]//subsample_ratio)
    A = W.T @ W ## Needed for gradient computation
    grad = W.T @ (W @ H0 - X)
    while (i < np.random.choice(sub_iter)):
        step_size = (1 / (((i + 1) ** (1)) * (np.trace(A) + 1)))
        H1 -= step_size * grad 
        if nonnegativity:
            H1 = np.maximum(H1, 0)  # nonnegativity constraint
        i = i + 1
    return H1


def ALS(X,
        n_components = 10, # number of columns in the dictionary matrix W
        n_iter=100,
        a0 = 0, # L1 regularizer for H
        a1 = 0, # L1 regularizer for W
        a12 = 0, # L2 regularizer for W
        H_nonnegativity=True,
        W_nonnegativity=True,
        compute_recons_error=False,
        subsample_ratio = 10):
    
        '''
        Given data matrix X, use alternating least squares to find factors W,H so that 
                                || X - WH ||_{F}^2 + a0*|H|_{1} + a1*|W|_{1} + a12 * |W|_{F}^{2}
        is minimized (at least locally)
        '''
        
        d, n = X.shape
        r = n_components
        
        #normalization = np.linalg.norm(X.reshape(-1,1),1)/np.product(X.shape) # avg entry of X
        #print('!!! avg entry of X', normalization)
        #X = X/normalization

        # Initialize factors 
        W = np.random.rand(d,r)
        H = np.random.rand(r,n) 
        # H = H * np.linalg.norm(X) / np.linalg.norm(H)
        for i in trange(n_iter):
            #H = coding_within_radius(X, W.copy(), H.copy(), a1=a0, nonnegativity=H_nonnegativity, subsample_ratio=subsample_ratio)
            #W = coding_within_radius(X.T, H.copy().T, W.copy().T, a1=a1, a2=a12, nonnegativity=W_nonnegativity, subsample_ratio=subsample_ratio).T
            H = coding(X, W.copy(), H.copy(), a1=a0, nonnegativity=H_nonnegativity, subsample_ratio=subsample_ratio)
            W = coding(X.T, H.copy().T, W.copy().T, a1=a1, a2=a12, nonnegativity=W_nonnegativity, subsample_ratio=subsample_ratio).T
            W /= np.linalg.norm(W)
            if compute_recons_error and (i % 10 == 0) :
                print('iteration %i, reconstruction error %f' % (i, np.linalg.norm(X-W@H)**2))
        return W, H

# %%
def display_graphs(title,
                     save_path,
                     grid_shape=[2,3],
                     fig_size=[10,10],
                     data = None, # [X, embs]
                     show_importance=False):

        # columns of X = vectorized k x k adjacency matrices
        # corresponding list in embs = sequence of nodes (may overalp)
        X, embs = data
        print('X.shape', X.shape)

        rows = grid_shape[0]
        cols = grid_shape[1]

        fig = plt.figure(figsize=fig_size, constrained_layout=False)
        # make outer gridspec

        idx = np.arange(X.shape[1])
        outer_grid = gridspec.GridSpec(nrows=rows, ncols=cols, wspace=0.02, hspace=0.02)

        # make nested gridspecs
        for i in range(rows * cols):
            a = i // cols
            b = i % rows

            Ndict_wspace = 0.05
            Ndict_hspace = 0.05

            # display graphs
            inner_grid = outer_grid[i].subgridspec(1, 1, wspace=Ndict_wspace, hspace=Ndict_hspace)

            # get rid of duplicate nodes
            A = X[:,idx[i]]
            A = X[:,idx[i]].reshape(int(np.sqrt(X.shape[0])), -1)
            H = nn.NNetwork()
            H.read_adj(A, embs[idx[i]])
            A_sub = H.get_adjacency_matrix()

            # read in as a nx graph for plotting
            G1 = nx.from_numpy_matrix(A_sub)
            ax = fig.add_subplot(inner_grid[0, 0])
            pos = nx.spring_layout(G1)
            edges = G1.edges()
            weights = [1*G1[u][v]['weight'] for u,v in edges]
            nx.draw(G1, with_labels=False, node_size=20, ax=ax, width=weights, label='Graph')

            ax.set_xticks([])
            ax.set_yticks([])

        plt.suptitle(title, fontsize=15)
        fig.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0)
        fig.savefig(save_path, bbox_inches='tight')

def display_dictionary(W, save_name=None, score=None, grid_shape=None, figsize=[10,10]):
    k = int(np.sqrt(W.shape[0]))
    rows = int(np.sqrt(W.shape[1]))
    cols = int(np.sqrt(W.shape[1]))
    if grid_shape is not None:
        rows = grid_shape[0]
        cols = grid_shape[1]
    
    figsize0=figsize
    if (score is None) and (grid_shape is not None):
        figsize0=(cols, rows)
    if (score is not None) and (grid_shape is not None):
        figsize0=(cols, rows+0.2)
    
    fig, axs = plt.subplots(nrows=rows, ncols=cols, figsize=figsize0,
                            subplot_kw={'xticks': [], 'yticks': []})
        
        
    for ax, i in zip(axs.flat, range(100)):
        if score is not None:
            idx = np.argsort(score)
            idx = np.flip(idx)    
            
            ax.imshow(W.T[idx[i]].reshape(k, k), cmap="viridis", interpolation='nearest')
            ax.set_xlabel('%1.2f' % score[i], fontsize=13)  # get the largest first
            ax.xaxis.set_label_coords(0.5, -0.05)
        else: 
            ax.imshow(W.T[i].reshape(k, k), cmap="viridis", interpolation='nearest')
            if score is not None:
                ax.set_xlabel('%1.2f' % score[i], fontsize=13)  # get the largest first
                ax.xaxis.set_label_coords(0.5, -0.05)
       
    plt.tight_layout()
    # plt.suptitle('Dictionary learned from patches of size %d' % k, fontsize=16)
    plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)
    
    if save_name is not None:
        plt.savefig( save_name, bbox_inches='tight')
    plt.show()
    
def display_dict_and_graph(title,
                           W, 
                           singular_values, 
                           save_path,
                           grid_shape=None,
                           fig_size=[10,10],
                           show_importance=False,
                           only_show_matrices=True):
        
        n_components = W.shape[1]
        k = int(np.sqrt(W.shape[0]))

        rows = np.round(np.sqrt(n_components))
        rows = rows.astype(int)
        if grid_shape is not None:
            rows = grid_shape[0]
            cols = grid_shape[1]
        else:
            if rows ** 2 == n_components:
                cols = rows
            else:
                cols = rows + 1

        if show_importance:
            # importance = np.sum(self.code, axis=1) / sum(sum(self.code))
            idx = np.argsort(singular_values)
            idx = np.flip(idx)
        else:
            idx = np.arange(W.shape[1])

        Ndict_wspace = 0.05
        Ndict_hspace = 0.05

        fig = plt.figure(figsize=fig_size, constrained_layout=False)
        ncols = 2 
        if only_show_matrices:
            ncols = 1
        outer_grid = gridspec.GridSpec(nrows=1, ncols=ncols, wspace=0.02, hspace=0.02)
        for t in np.arange(2):
            # make nested gridspecs

            if t == 0:
                ### Make gridspec
                inner_grid = outer_grid[t].subgridspec(rows, cols, wspace=Ndict_wspace, hspace=Ndict_hspace)
                #gs1 = fig.add_gridspec(nrows=rows, ncols=cols, wspace=0.05, hspace=0.05)

                for i in range(rows * cols):
                    a = i // cols
                    b = i % cols
                    ax = fig.add_subplot(inner_grid[a, b])
                    ax.imshow(W.T[idx[i]].reshape(k, k), cmap="viridis", interpolation='nearest')
                    # ax.set_xlabel('%1.2f' % importance[idx[i]], fontsize=13)  # get the largest first
                    # ax.xaxis.set_label_coords(0.5, -0.05)  # adjust location of importance appearing beneath patches
                    ax.set_xticks([])
                    ax.set_yticks([])
            if (t == 1) and not only_show_matrices:
                inner_grid = outer_grid[t].subgridspec(rows, cols, wspace=Ndict_wspace, hspace=Ndict_hspace)
                #gs1 = fig.add_gridspec(nrows=rows, ncols=cols, wspace=0.05, hspace=0.05)

                for i in range(rows * cols):
                    a = i // cols
                    b = i % cols

                    G1 = nx.from_numpy_matrix(W[:,idx[i]].reshape(int(np.sqrt(W.shape[0])),-1))
                    ax = fig.add_subplot(inner_grid[a, b])
                    pos = nx.spring_layout(G1)
                    edges = G1.edges()
                    weights = [2*G1[u][v]['weight'] for u,v in edges]
                    nx.draw(G1, with_labels=False, node_size=10, ax=ax, width=weights, label='Graph')
                    if show_importance:
                        ax.set_xlabel('%1.2f' % importance[idx[i]], fontsize=13)  # get the largest first
                        ax.xaxis.set_label_coords(0.5, -0.05)  # adjust location of importance appearing beneath patches

                    ax.set_xticks([])
                    ax.set_yticks([])

        if title is not None:
            plt.suptitle(title, fontsize=25)
        fig.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0)
        fig.savefig(save_path, bbox_inches='tight')
